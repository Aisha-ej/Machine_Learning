# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Student_Performance.csv')
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.size
# Out:
# 60000

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

lab = LabelEncoder()
Extracurricular_Activities_Encoder = lab.fit_transform(df['Extracurricular Activities'])
Extracurricular_Activities_Encoder
# Out:
# array([1, 0, 1, ..., 1, 1, 0], shape=(10000,))

# %%
feature = list(zip(df['Hours Studied'],df['Previous Scores'],Extracurricular_Activities_Encoder,df['Sleep Hours'],df['Sample Question Papers Practiced']))
feature
# Out:
# [(7, 99, np.int64(1), 9, 1),
#  (4, 82, np.int64(0), 4, 2),
#  (8, 51, np.int64(1), 7, 2),
#  (5, 52, np.int64(1), 5, 2),
#  (7, 75, np.int64(0), 8, 5),
#  (3, 78, np.int64(0), 9, 6),
#  (7, 73, np.int64(1), 5, 6),
#  (8, 45, np.int64(1), 4, 6),
#  (5, 77, np.int64(0), 8, 2),
#  (4, 89, np.int64(0), 4, 0),
#  (8, 91, np.int64(0), 4, 5),
#  (8, 79, np.int64(0), 6, 2),
#  (3, 47, np.int64(0), 9, 2),
#  (6, 47, np.int64(0), 4, 2),
#  (5, 79, np.int64(0), 7, 8),
#  (2, 72, np.int64(0), 4, 3),
#  (8, 73, np.int64(1), 8, 4),
#  (6, 83, np.int64(1), 7, 2),
#  (2, 54, np.int64(1), 4, 9),
#  (5, 75, np.int64(0), 7, 0),
#  (1, 99, np.int64(1), 4, 3),
#  (6, 96, np.int64(0), 9, 0),
#  (9, 74, np.int64(1), 7, 6),
#  (1, 85, np.int64(0), 5, 6),
#  (3, 61, np.int64(0), 6, 3),
#  (7, 62, np.int64(1), 7, 4),
#  (4, 79, np.int64(0), 8, 9),
#  (9, 84, np.int64(1), 6, 6),
#  (3, 94, np.int64(1), 6, 5),
#  (5, 90, np.int64(1), 4, 3),
#  (3, 61, np.int64(1), 7, 3),
#  (7, 44, np.int64(1), 9, 1),
# ...

# %%
x = feature
y= df.iloc[:,-1]

# %%
df.corr(numeric_only=True)
# Out:
#                                   Hours Studied  Previous Scores  Sleep Hours  \
# Hours Studied                          1.000000        -0.012390     0.001245
# Previous Scores                       -0.012390         1.000000     0.005944
# Sleep Hours                            0.001245         0.005944     1.000000
# Sample Question Papers Practiced       0.017463         0.007888     0.003990
# Performance Index                      0.373730         0.915189     0.048106
#
#                                   Sample Question Papers Practiced  \
# Hours Studied                                             0.017463
# Previous Scores                                           0.007888
# Sleep Hours                                               0.003990
# Sample Question Papers Practiced                          1.000000
# Performance Index                                         0.043268
#
#                                   Performance Index
# ...

# %%
sns.regplot(x=df['Hours Studied'],y=y)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Performance Index'>

# %%
sns.regplot(x=df['Previous Scores'],y=y)
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Performance Index'>

# %%
sns.regplot(x=df['Sleep Hours'],y=y)
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Performance Index'>

# %%
sns.regplot(x=df['Sample Question Papers Practiced'],y=y)
# Out:
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Performance Index'>

# %%
#sns.regplot(x=df['Extracurricular Activities'],y=y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30,random_state=42)
x_train
# Out:
# [(4, 99, np.int64(1), 6, 1),
#  (6, 90, np.int64(1), 9, 3),
#  (8, 57, np.int64(0), 6, 1),
#  (6, 92, np.int64(1), 8, 7),
#  (6, 64, np.int64(1), 8, 4),
#  (5, 60, np.int64(1), 6, 6),
#  (1, 90, np.int64(0), 5, 6),
#  (3, 80, np.int64(0), 7, 3),
#  (3, 55, np.int64(1), 5, 8),
#  (5, 54, np.int64(1), 6, 6),
#  (8, 76, np.int64(0), 8, 4),
#  (7, 73, np.int64(0), 5, 4),
#  (2, 72, np.int64(1), 4, 1),
#  (6, 60, np.int64(0), 9, 8),
#  (2, 65, np.int64(1), 6, 2),
#  (2, 44, np.int64(1), 9, 8),
#  (1, 94, np.int64(1), 5, 1),
#  (3, 99, np.int64(1), 6, 8),
#  (5, 57, np.int64(0), 9, 1),
#  (4, 93, np.int64(1), 5, 2),
#  (3, 86, np.int64(1), 5, 3),
#  (9, 80, np.int64(1), 6, 1),
#  (3, 74, np.int64(0), 6, 6),
#  (8, 70, np.int64(0), 8, 5),
#  (5, 49, np.int64(1), 5, 0),
#  (7, 41, np.int64(0), 4, 7),
#  (2, 87, np.int64(1), 7, 6),
#  (8, 54, np.int64(1), 5, 9),
#  (7, 64, np.int64(1), 8, 5),
#  (7, 80, np.int64(0), 9, 6),
#  (5, 47, np.int64(1), 8, 6),
#  (7, 76, np.int64(0), 8, 8),
# ...
